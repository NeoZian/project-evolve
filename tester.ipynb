# %%
from sqlalchemy.engine import URL
import sqlalchemy as sa

url_object = URL.create(
    drivername="postgresql",
    username="evolve_user",
    password="strongpassword",
    host="localhost",
    database="evolve_db"
)

# 2. Create the engine using that URL
engine = sa.create_engine(url_object)

with engine.connect() as conn:
    print(".....Connected to PostgreSQL successfully!")
# Out:
# .....Connected to PostgreSQL successfully!

# %%
from sqlalchemy import create_engine, text

engine = create_engine("postgresql://evolve_user:strongpassword@localhost/evolve_db")
with engine.connect() as conn:
    conn.execute(text("""
        CREATE TABLE IF NOT EXISTS faculty_feedback (
            feedback_id SERIAL PRIMARY KEY,
            faculty_id INTEGER NOT NULL,
            understandability_score INTEGER CHECK (understandability_score BETWEEN 1 AND 5),
            trust_score INTEGER CHECK (trust_score BETWEEN 1 AND 5),
            comment TEXT,
            xai_viewed BOOLEAN DEFAULT FALSE,
            created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
        )
    """))
    conn.commit()
print("Table ready")
# Out:
# Table ready

# %%
SELECT faculty_id, final_evaluation_score, blockchain_tx_hash, logged_at 
FROM evaluation_results_with_blockchain 
LIMIT 5;

# %%
from sqlalchemy import create_engine, text
import pandas as pd

# Create engine
engine = create_engine("postgresql://evolve_user:strongpassword@localhost/evolve_db")

# Check the data
query = """
SELECT 
    faculty_id, 
    final_evaluation_score, 
    blockchain_tx_hash, 
    result_hash,
    logged_at 
FROM evaluation_results_with_blockchain 
LIMIT 10;
"""

df = pd.read_sql(text(query), engine)

print(f"Total records in blockchain table: {len(df)}")
print("\nFirst 10 records:")
display(df)   # This shows a nice table in Jupyter
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File ~/project-evolve/venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/project-evolve/venv/lib/python3.12/site-packages/sqlalchemy/engine/default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# UndefinedColumn: column "logged_at" does not exist
# LINE 7:     logged_at
#             ^
#
#
# ...
